# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import seaborn as sns

# %%
os.chdir("D:\Omdena Topek Chapter - Automated LVEF Assessment\Heart Failure Prediction Dataset")

# %%
heart = pd.read_csv("heart.csv")

# %%
heart.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
heart.tail(5)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
heart.shape
# Out:
# (918, 12)

# %%
heart.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
heart.duplicated().sum()
# Out:
# 0

# %%
heart.size
# Out:
# 11016

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
heart.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
heart.sample(n = 5 )
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 5     39   M           NAP        120          339          0     Normal
# 668   63   F           ATA        140          195          0     Normal
# 121   52   F           NAP        125          272          0     Normal
# 912   57   F           ASY        140          241          0     Normal
# 884   67   M           ASY        160          286          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 5      170              N      0.0       Up             0
# 668    179              N      0.0       Up             0
# 121    139              N      0.0       Up             0
# 912    123              Y      0.2     Flat             1
# 884    108              Y      1.5     Flat             1

# %%
heart.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
heart.ChestPainType.value_counts()
# Out:
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
sns.displot(heart["ChestPainType"])
print("TA : Typical Angina", 
      "ATA : Atypical Angina",  
      "NAP : Non-Anginal Pain" ,
      "ASY : Asymptonic")
# Out:
# TA : Typical Angina ATA : Atypical Angina NAP : Non-Anginal Pain ASY : Asymptonic

# %%
sns.displot(heart["Age"])

# %%
sns.displot(heart["Sex"])

# %%
sns.scatterplot(x='Age',y='Sex',data=heart,hue='ChestPainType')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Sex'>

# %%
plt.figure(figsize=(30,20))
sns.barplot(data = heart, x = "Age", y = "RestingBP")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='RestingBP'>

# %%
plt.figure(figsize=(30,20))
sns.barplot(data = heart, x = "Age", y = "Cholesterol", hue = "Sex")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Cholesterol'>

# %%
plt.figure(figsize=(30,20))
sns.barplot(data = heart, x = "Age", y = "FastingBS", hue = "Sex")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='FastingBS'>

# %%
plt.figure(figsize=(20,20))
sns.barplot(data = heart, x = "Age", y = "RestingECG", hue = "Sex")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='RestingECG'>

# %%
plt.figure(figsize=(20,20))
sns.barplot(data = heart, x = "Age", y = "MaxHR", hue = "Sex")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='MaxHR'>

# %%
plt.figure(figsize=(20,20))
sns.barplot(data = heart, x = "Age", y = "ExerciseAngina", hue = "Sex")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='ExerciseAngina'>

# %%
plt.figure(figsize = (20,10))
sns.barplot(data = heart, x = "Age", y = "Oldpeak", hue = "Sex")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Oldpeak'>

# %%
plt.figure(figsize = (10,10))
sns.barplot(data = heart, x = "Age", y = "ST_Slope", hue= "Sex")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='ST_Slope'>

# %%
sns.violinplot(x = "HeartDisease", y = "Age", hue = "Sex", data = heart, palette = "Blues")
# Out:
# <AxesSubplot: xlabel='HeartDisease', ylabel='Age'>

# %%
heart.corr()
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_16156\1516287138.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heart.corr()
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# ...

# %%
sns.heatmap(heart.corr(),cmap = 'YlGnBu')
plt.title("CORRELATION MAP", fontweight = "bold", fontsize = 16)
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_16156\3250332501.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(heart.corr(),cmap = 'YlGnBu')
# Text(0.5, 1.0, 'CORRELATION MAP')

# %%
sns.pairplot(heart)
